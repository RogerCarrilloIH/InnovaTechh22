# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 1.5 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/jovyan/data/08072022-empresas-habilitadas.csv', encoding='latin-1')

# %%
df.head()
# Out:
#              Giro empresa                        Empresa Exportadora  \
# 0  ALIMENTO PARA ANIMALES  MALTA TEXO DE MÉXICO S.A DE C.V (MORELOS)
# 1  ALIMENTO PARA ANIMALES  MALTA TEXO DE MÉXICO S.A DE C.V (JALISCO)
# 2  ALIMENTO PARA ANIMALES           NESTLÉ PURINA S.A DE C.V (SILAO)
# 3  ALIMENTO PARA ANIMALES      NESTLÉ PURINA S.A DE C.V (CUAUTITLÁN)
# 4  ALIMENTO PARA ANIMALES    CAMPI ALIMENTOS S.A. DE C.V. (EZEQUIEL)
#
#   País destino                      Producto
# 0        CUBA   ALIMENTO PARA CONSUMO ANIMAL
# 1        CUBA   ALIMENTO PARA CONSUMO ANIMAL
# 2        CUBA   ALIMENTO PARA CONSUMO ANIMAL
# 3        CUBA   ALIMENTO PARA CONSUMO ANIMAL
# 4        CUBA   ALIMENTO PARA CONSUMO ANIMAL

# %%
df['name']=  [s[:(s.rfind(' S.A'))] for s in  df['Empresa Exportadora']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_32/3474831486.py in <module>
# ----> 1 df['name']=  [s[:(s.rfind(' S.A'))] for s in  df['Empresa Exportadora']]
#
# /tmp/ipykernel_32/3474831486.py in <listcomp>(.0)
# ----> 1 df['name']=  [s[:(s.rfind(' S.A'))] for s in  df['Empresa Exportadora']]
#
# AttributeError: 'float' object has no attribute 'rfind'

# %%
ecx = pd.read_excel('/home/jovyan/data/DATOS_ABIERTOS_2021[2].xlsx')

# %%
[s if str(s)[0:3]=='ABC' else 'none' for s in ecx['PROVEEDOR']]
# Out:
# ['none',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'ABC AEROLINEAS, SA DE CV',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
# ...

# %%
ecx['name']=[str(s)[:-10] if (str(s)[-10:-9] == ' ' or str(s)[-10:-9] == ',')
                     else (str(s)[:-4] if str(s)[-4:] == ', SC'
                        else str(s)[:-9]) for s in ecx['PROVEEDOR']]

# %%
ecx.head()
# Out:
#       ID_EXP       FECHA_INGRESO            FECHA_FIN  \
# 0  2021_3451 2021-01-03 11:19:00                    -
# 1   2021_180 2021-01-04 12:31:00  2021-02-10 00:00:00
# 2   2021_181 2021-01-04 12:49:00                    -
# 3   2021_182 2021-01-04 13:10:00                    -
# 4   2021_345 2021-01-04 16:00:00  2021-05-25 00:00:00
#
#                 TIPO_CONCILIACION ESTADO_PROCESAL                 PROVEEDOR  \
# 0                      En Proceso      En Trámite  DENTIX MEXICO HEALTH, SC
# 1  Turnada a Concil Resi p/ segui   Desistimiento  ABC AEROLINEAS, SA DE CV
# 2  Turnada a Concil Resi p/ segui      En Trámite  ABC AEROLINEAS, SA DE CV
# 3  Turnada a Concil Resi p/ segui      En Trámite  ABC AEROLINEAS, SA DE CV
# 4   Turnada a Concil Person p/seg   No Conciliada  ABC AEROLINEAS, SA DE CV
#
#   NOMBRE_COMERCIAL                             GIRO  \
# 0         DENTIMEX  HOSPITAL, CLÍNICAS Y SANATORIOS
# 1         INTERJET              AEROLÍNEA COMERCIAL
# ...

# %%
data_bbva = pd.read_csv('/home/jovyan/data/Final_Data_Hackathon_2022.csv')

# %%
data_bbva['name'] = [s[:-10] if (s[-10:-9] == ' ' or s[-10:-9] == ',')
                     else (s[:-6] if s[-5:] == 'SA CV'
                        else s[:-9]) for s in data_bbva['NombComp']]

# %%
data_bbva.head()
# Out:
#    Index               Nombre1             Nombre2 Nombre3       Direccion1  \
# 0      0  CENTRO PAPELERO SUN-       RISE SA DE CV     NaN           REGINA
# 1      1  ECOTRANSPORTES ZERME  NO GARCIA SA DE CV     NaN       VALPARAISO
# 2      2  TECNOLAMINAS, S.A. D              E C#V#     NaN    CALLE DEL RIO
# 3      3         MASVIDA SA CV                 NaN     NaN         HAMBURGO
# 4      4  INTEGRADORA COMERCIA       L VS SA DE CV     NaN  PEDRO GUZMAN 17
#
#   Direccion2 Direccion3               Colonia          MunicipioDel     CP  \
# 0        135     ACCE A       CENTRO #AREA 9#            CUAUHTEMOC   6090
# 1         65          1   TEPEYAC INSURGENTES      GUSTAVO A MADERO   7020
# 2          2        NaN  INDUSTRIAL ALCE BLAN             NAUCALPAN  53370
# 3        141        03A                JUAREZ            CUAUHTEMOC   6600
# 4    TORRE 8    DEP 604  LOMAS DE SAN LORENZO  ATIZAPAN DE ZARAGOZA  52975
#
# ...

# %%
unionProfeco = pd.merge(left=ecx,right=data_bbva, left_on='name', right_on='name')

# %%
unionProfeco.head()
# Out:
#        ID_EXP       FECHA_INGRESO            FECHA_FIN  \
# 0    2021_436 2021-01-04 11:38:00  2021-03-31 00:00:00
# 1    2021_447 2021-01-07 10:49:00  2022-01-11 00:00:00
# 2  2021_40029 2021-07-05 12:14:00                    -
# 3   2021_3675 2021-01-04 10:06:00                    -
# 4  2021_10228 2021-02-26 13:44:00  2021-10-15 00:00:00
#
#                TIPO_CONCILIACION ESTADO_PROCESAL  \
# 0  Turnada a Concil Person p/seg   Desistimiento
# 1  Turnada a Concil Person p/seg   Desistimiento
# 2  Turnada a Concil Person p/seg      En Trámite
# 3  Turnada a Concil Person p/seg      En Trámite
# 4  Turnada a Concil Person p/seg   No Conciliada
#
#                        PROVEEDOR               NOMBRE_COMERCIAL  \
# 0  REFRIMART DE MEXICO, SA DE CV  REFRIMART DE MEXICO, SA DE CV
# 1  REFRIMART DE MEXICO, SA DE CV  REFRIMART DE MEXICO, SA DE CV
# 2  REFRIMART DE MEXICO, SA DE CV  REFRIMART DE MEXICO, SA DE CV
# 3     VISION PRENDARIA, SA DE CV                    MEGAEMPEÑOS
# ...
